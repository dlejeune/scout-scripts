# %%
import pandas as pd
import numpy as np
def trim_name(name_str):
    name_arr = name_str.split(" ")
    initial = name_arr[1][0:1]

    return "{} {}".format(name_arr[0], initial)

FULL = True

# %%
scouts = pd.read_excel("data.xlsx")
scouts["Patrol"] = scouts["Patrol"].astype("category")
scouts
# Out:
#           Name            Surname                FullName        Patrol  \
# 0         Nina            Starke              Nina Starke     Bateleurs
# 1       Oliver          Ringrose          Oliver Ringrose     Bateleurs
# 2    Mackenzie             Block          Mackenzie Block     Bateleurs
# 3        Jason        Franciscus         Jason Franciscus     Bateleurs
# 4      Timothy      Van Zyl-smit     Timothy Van Zyl-smit     Bateleurs
# 5       Thomas          Cilliers          Thomas Cilliers     Bateleurs
# 6        Emily            Gilham             Emily Gilham    Bateleurs
# 7       Rachel          Cilliers          Rachel Cilliers  Bokmakieries
# 8      Matthew            Miller           Matthew Miller  Bokmakieries
# 9   Kupakwashe          Muringai      Kupakwashe Muringai  Bokmakieries
# 10     Tristan             Staak            Tristan Staak  Bokmakieries
# 11         Zoë             Halse                Zoë Halse  Bokmakieries
# ...

# %%
activities = pd.read_csv("activities.csv", header = 2)
activities
# Out:
#             Date                      Title Primary In Charge  \
# 0   20 Jan (Thu)            Obstacle Course   Daniel Le Jeune
# 1   22 Jan (Sat)        Swimming Scoutcraft             Susan
# 2   27 Jan (Thu)             Fun Pioneering    Matthew Gammon
# 3   29 Jan (Sat)         Pioneer Scoutcraft            Daniel
# 4    3 Feb (Thu)       Cooking with a twist     Thomas Roomes
# 5   10 Feb (Thu)             Urban Kloofing     Fraser Hewson
# 6   13 Feb (Sun)                   Kloofing            Daniel
# 7   17 Feb (Thu)  Water Baloon Hunger Games    Natasha Roomes
# 8   19 Feb (Sat)                Rayner Prep             Becca
# 9   24 Feb (Thu)            Patrol Evenings   Daniel Le Jeune
# 10  26 Feb (Sat)           Kontiki Prebuild            Daniel
# 11  27 Feb (Sun)                     Caving          Jonathan
# 12   3 Mar (Thu)                CoH Meeting   Daniel Le Jeune
# 13   5 Mar (Sat)                     Rayner             Emily
# ...

# %%
for patrol in scouts.loc[ :, ["Patrol"]]:
   print(patrol)
# Out:
# Patrol
